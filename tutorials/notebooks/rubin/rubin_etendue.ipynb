# %% [markdown]
# # Calculating the Étendue of the Vera C. Rubin Observatory
#
# Course: EDUCADO 2026
# Topic: Survey telescope design and figures of merit
#
# Étendue ($A\Omega$) quantifies a telescope's survey power. It is the product of the
# effective collecting area $A_{\mathrm{eff}}$ and the solid angle $\Omega$ of the field of view:
#
# $$A\Omega = A_{\mathrm{eff}} \times \Omega$$
#
# This notebook walks through each step of the calculation to derive the Rubin Observatory canonical value of ≈ 319 m² deg².

# %% [markdown]
# Primary references used in this notebook:
#
# **[LOP]** Ivezić, Ž. et al. 2019, *ApJ*, 873, 111 — *"LSST: From Science Drivers to Reference Design and Anticipated Data Products"*
# arXiv:0805.2366 · DOI:10.3847/1538-4357/ab042c · short URL: `ls.st/lop`
# → Source for: étendue (319 m²·deg²), effective collecting area (35 m²), FOV diameter (3.5°)
#
# **[RKN]** Rubin Observatory Key Numbers: https://rubinobservatory.org/for-scientists/rubin-101/key-numbers
# → Source for: étendue, effective collecting area, FOV
#
# **[MIR]** Rubin Observatory Mirror page: https://www.lsst.org/about/tel-site/mirror
# → Source for: M1 outer diameter (8.4 m glass blank), M1 inner diameter, M2 diameter
#
# **[CLV]** Claver, C. F. et al. — *"An Overview of the LSST Telescope and Site"*
# https://www.lsst.org/sites/default/files/docs/Claver_086.18.pdf
# → Source for: individual mirror dimensions and optical design geometry
#
# > **Note:** The individual mirror diameters (M1, M2, M3) are **not** in LOP Table 1.
# > LOP Table 1 gives high-level system parameters only (effective aperture, collecting area, FOV, étendue).
# > Mirror dimensions come from [MIR] and [CLV].

# %%
import numpy as np
import pandas as pd

import holoviews as hv
from holoviews import opts
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='71aa815e-b6de-43b1-9388-e6f1a30b5a48'>
#   <div id="e52dfa6b-9b30-41f2-8082-aecd6af0b7f6" data-root-id="71aa815e-b6de-43b1-9388-e6f1a30b5a48" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## 1. Telescope Parameters
#
# Rubin uses a unique three-mirror anastigmat design where the primary mirror (M1)
# and the tertiary mirror (M3) are polished onto the same monolithic glass substrate.
# This means M1 is an annulus and does not extend to the centre.

# %%
# Mirror dimensions (metres)
# Sources: [MIR] Rubin Observatory Mirror page, [CLV] Claver et al.
D_M1_outer = 8.4      # M1 glass blank outer diameter [MIR]
D_M1_inner = 5.012    # M1 inner diameter / M3 outer diameter [CLV]
D_M2       = 3.42     # M2 (secondary) diameter [MIR, CLV]

# Field of view — from LOP Table 1 and [RKN]
fov_diameter_deg = 3.5

print(f"M1 outer diameter : {D_M1_outer} m   (source: [MIR, CLV])")
print(f"M1 inner diameter : {D_M1_inner} m  (source: [CLV])")
print(f"M2 diameter       : {D_M2} m   (source: [MIR, CLV])")
print(f"FoV diameter      : {fov_diameter_deg}°     (source: LOP Table 1, [RKN])")
# Out:
# M1 outer diameter : 8.4 m   (source: [MIR, CLV])
# M1 inner diameter : 5.012 m  (source: [CLV])
# M2 diameter       : 3.42 m   (source: [MIR, CLV])
# FoV diameter      : 3.5°     (source: LOP Table 1, [RKN])

# %%
# Additional obscuration fraction (camera body, spider vanes, baffles)
additional_obscuration = 0.07  # ~7 %

# %% [markdown]
# ## 2. Geometric Collecting Area of the M1 Annulus
#
# Because M2 (3.42 m) is *smaller* than the M1 central hole (5.012 m), the secondary
# does not create any extra obscuration; the hole in M1 already accounts for it.
#
# $$A_{M1} = \frac{\pi}{4}\left(D_{\mathrm{outer}}^{2} - D_{\mathrm{inner}}^{2}\right)$$

# %%
A_M1 = (np.pi / 4) * (D_M1_outer**2 - D_M1_inner**2)

print(f"M1 annulus area = (π/4) × ({D_M1_outer}² − {D_M1_inner}²)")
print(f"                = (π/4) × ({D_M1_outer**2:.2f} − {D_M1_inner**2:.3f})")
print(f"                = (π/4) × {D_M1_outer**2 - D_M1_inner**2:.3f}")
print(f"                = {A_M1:.2f} m²")
# Out:
# M1 annulus area = (π/4) × (8.4² − 5.012²)
#                 = (π/4) × (70.56 − 25.120)
#                 = (π/4) × 45.440
#                 = 35.69 m²

# %% [markdown]
# ## 3. Effective Collecting Area
#
# We apply a correction for the additional obscuration from the camera body,
# spider vanes, and baffling (~7 %):
#
# $$A_{\mathrm{eff}} = A_{M1} \times (1 - f_{\mathrm{obsc}})$$

# %%
A_eff = A_M1 * (1 - additional_obscuration)

print(f"Additional obscuration : {additional_obscuration*100:.0f} %")
print(f"A_eff = {A_M1:.2f} × {1 - additional_obscuration:.2f} = {A_eff:.2f} m²")
# Out:
# Additional obscuration : 7 %
# A_eff = 35.69 × 0.93 = 33.19 m²

# %% [markdown]
# ## 4. Field-of-View Solid Angle
#
# The focal plane subtends a 3.5° diameter circle on the sky.
#
# ### Flat-sky (small-angle) approximation
#
# $$\Omega \approx \pi \left(\frac{\theta_{\mathrm{FoV}}}{2}\right)^{2} \quad [\mathrm{deg}^{2}]$$
#
# ### Exact spherical formula
#
# $$\Omega_{\mathrm{exact}} = 2\pi\left(1 - \cos\frac{\theta_{\mathrm{FoV}}}{2}\right) \quad [\mathrm{sr}]$$

# %%
# --- In square degrees (flat-sky) ---
half_angle_deg = fov_diameter_deg / 2
Omega_deg2 = np.pi * half_angle_deg**2

# --- Exact spherical ---
half_angle_rad = np.radians(half_angle_deg)
Omega_sr = 2 * np.pi * (1 - np.cos(half_angle_rad))
Omega_sr_to_deg2 = Omega_sr * (180 / np.pi)**2

print(f"Half-angle           : {half_angle_deg}° = {half_angle_rad:.6f} rad")
print(f"Ω (flat-sky approx)  : {Omega_deg2:.4f} deg²")
print(f"Ω (exact spherical)  : {Omega_sr_to_deg2:.4f} deg²")
print(f"\nDifference           : {abs(Omega_deg2 - Omega_sr_to_deg2):.4f} deg² "
      f"({abs(Omega_deg2 - Omega_sr_to_deg2)/Omega_deg2*100:.3f} %)")
print("\n→ At 3.5° the flat-sky approximation is excellent.")
# Out:
# Half-angle           : 1.75° = 0.030543 rad
# Ω (flat-sky approx)  : 9.6211 deg²
# Ω (exact spherical)  : 9.6204 deg²
#
# Difference           : 0.0007 deg² (0.008 %)
#
# → At 3.5° the flat-sky approximation is excellent.

# %% [markdown]
# ## 5. Étendue Calculation
#
# $$A\Omega = A_{\mathrm{eff}} \times \Omega$$

# %%
etendue = A_eff * Omega_deg2
print(f"  A_eff  = {A_eff:.2f} m²")
print(f"  Ω      = {Omega_deg2:.4f} deg²")
print(f"  ────────────────────────────────")
print(f"  AΩ     = {etendue:.1f} m² deg²")
# Out:
#   A_eff  = 33.19 m²
#   Ω      = 9.6211 deg²
#   ────────────────────────────────
#   AΩ     = 319.3 m² deg²

# %% [markdown]
# ## 6. Sensitivity to Assumptions
#
# The canonical 319 value depends on the assumed additional obscuration.
# Let's see how the étendue varies.

# %%
print(f"{'Obscuration (%)':>16}  {'A_eff (m²)':>11}  {'AΩ (m² deg²)':>13}")
print("-" * 46)

for obsc_pct in [0, 3, 5, 7, 10]:
    A = A_M1 * (1 - obsc_pct / 100)
    AO = A * Omega_deg2
    marker = "  ← canonical" if obsc_pct == 7 else ""
    print(f"{obsc_pct:>15.0f}%  {A:>11.2f}  {AO:>13.1f}{marker}")
# Out:
#  Obscuration (%)   A_eff (m²)   AΩ (m² deg²)
# ----------------------------------------------
#               0%        35.69          343.4
#               3%        34.62          333.1
#               5%        33.90          326.2
#               7%        33.19          319.3  ← canonical
#              10%        32.12          309.0

# %% [markdown]
# ## 7. Comparison with Other Survey Telescopes

# %%
SURVEY   = 'Wide-field surveys'
SPACE    = 'Space observatories'
NARROW   = 'Narrow-field / Large aperture'
FUTURE   = 'Future ELTs'

telescopes = {
    # Wide-field survey telescopes
    'VLT (FORS2)':         {'A_m2': 52.0,  'FOV_deg2':  0.013, 'E':   0.68, 'cat': NARROW,  'year': 1999, 'ref': 'Appenzeller+1998',     'note': 'Huge mirror, tiny FOV; built for depth not surveys'},
    'CFHT/MegaCam':        {'A_m2': 10.0,  'FOV_deg2':  1.000, 'E':  10.00, 'cat': SURVEY,  'year': 2003, 'ref': 'Boulade+2003',         'note': 'Excellent seeing, smaller FOV limits étendue'},
    'SkyMapper':           {'A_m2':  1.75, 'FOV_deg2':  5.700, 'E':  10.00, 'cat': SURVEY,  'year': 2008, 'ref': 'Keller+2007',          'note': 'Southern sky survey, modest étendue'},
    'VISTA/VIRCAM':        {'A_m2':  8.7,  'FOV_deg2':  0.600, 'E':   5.20, 'cat': SURVEY,  'year': 2009, 'ref': 'Emerson+2006',         'note': 'ESO near-IR survey telescope; dedicated wide-field'},
    'Pan-STARRS PS1':      {'A_m2':  2.54, 'FOV_deg2':  7.000, 'E':  18.00, 'cat': SURVEY,  'year': 2010, 'ref': 'Chambers+2016',        'note': 'Much smaller mirror, still wide-field; PS2 similar'},
    'Subaru/HSC':          {'A_m2': 52.8,  'FOV_deg2':  1.770, 'E':  94.00, 'cat': SURVEY,  'year': 2012, 'ref': 'Miyazaki+2018',        'note': 'Big aperture, large FOV, smaller than LSST'},
    'DES/DECam':           {'A_m2': 12.3,  'FOV_deg2':  3.000, 'E':  37.00, 'cat': SURVEY,  'year': 2013, 'ref': 'Flaugher+2015',        'note': 'Medium étendue, used for Dark Energy Survey'},
    'ZTF (Palomar 48")':   {'A_m2':  1.0,  'FOV_deg2': 47.000, 'E':  47.00, 'cat': SURVEY,  'year': 2018, 'ref': 'Bellm+2019',           'note': 'Huge FOV compensates for small aperture'},
    'JWST NIRCam':         {'A_m2': 25.0,  'FOV_deg2':  0.001, 'E':   0.025,'cat': SPACE,   'year': 2022, 'ref': 'Gardner+2006',         'note': 'Large mirror but tiny FOV; not a survey telescope'},
    'Euclid VIS':          {'A_m2':  1.01, 'FOV_deg2':  0.540, 'E':   0.55, 'cat': SPACE,   'year': 2023, 'ref': 'Euclid Coll.+2022',    'note': 'ESA dark-energy mission; tiny FOV by design'},
    'Rubin/LSST':          {'A_m2': 35.0,  'FOV_deg2':  9.620, 'E': 319.00, 'cat': SURVEY,  'year': 2025, 'ref': 'LOP / [RKN]',         'note': 'Next-generation survey; LSST'},
    'Roman (Nancy Grace)': {'A_m2':  3.76, 'FOV_deg2':  0.280, 'E':   1.05, 'cat': SPACE,   'year': 2027, 'ref': 'Spergel+2015',         'note': 'NASA wide-field infrared; 18× Hubble FOV'},
    'ELT (39 m)':          {'A_m2': 978.0, 'FOV_deg2':  0.003, 'E':   2.93, 'cat': FUTURE,  'year': 2028, 'ref': 'ELT Blue Book 2011',   'note': 'Enormous area, tiny FOV; depth not survey speed'},
}

etendue_official = telescopes['Rubin/LSST']['E']

df_tel = pd.DataFrame([
    {'Telescope': k, 'Category': v['cat'], 'Year': v['year'],
     'A_eff (m²)': v['A_m2'], 'FOV (deg²)': v['FOV_deg2'],
     'Étendue (m²·deg²)': v['E'], 'Reference': v['ref'], 'Note': v['note']}
    for k, v in telescopes.items()
])

# Sort by first-light / survey-start year (ascending)
df_tel = df_tel.sort_values('Year', ascending=True).reset_index(drop=True)

df_tel['Ratio to Rubin'] = df_tel['Étendue (m²·deg²)'].apply(lambda x: f'{x/etendue_official:.4f}')

print(f"{'Year':<6} {'Telescope':<22} {'Category':<28} {'A_eff':>7} {'FOV':>8} {'AΩ':>8} {'Ratio':>8}")
print("=" * 95)
for _, row in df_tel.iterrows():
    print(f"  {row['Year']:<4} {row['Telescope']:<22} {row['Category']:<28} "
          f"{row['A_eff (m²)']:>7.2f} {row['FOV (deg²)']:>8.4f} "
          f"{row['Étendue (m²·deg²)']:>8.2f} {row['Ratio to Rubin']:>8}")
# Out:
# Year   Telescope              Category                       A_eff      FOV       AΩ    Ratio
# ...
#   1999 VLT (FORS2)            Narrow-field / Large aperture   52.00   0.0130     0.68   0.0021
#   2003 CFHT/MegaCam           Wide-field surveys             10.00   1.0000    10.00   0.0313
#   2008 SkyMapper              Wide-field surveys              1.75   5.7000    10.00   0.0313
#   2009 VISTA/VIRCAM           Wide-field surveys              8.70   0.6000     5.20   0.0163
#   2010 Pan-STARRS PS1         Wide-field surveys              2.54   7.0000    18.00   0.0564
#   2012 Subaru/HSC             Wide-field surveys             52.80   1.7700    94.00   0.2947
#   2013 DES/DECam              Wide-field surveys             12.30   3.0000    37.00   0.1160
#   2018 ZTF (Palomar 48")      Wide-field surveys              1.00  47.0000    47.00   0.1473
#   2022 JWST NIRCam            Space observatories            25.00   0.0010     0.03   0.0001
# ...

# %%
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')

# ───────────────────────────────
# Prepare dataframe
# ───────────────────────────────

plot_df = df_tel.copy().reset_index(drop=True)
plot_df['x'] = range(len(plot_df))

CAT_COLORS = {
    SURVEY: '#4488bb',
    SPACE:  '#e07a2f',
    NARROW: '#9467bd',
    FUTURE: '#d62728',
}
RUBIN_COLOR = '#2ca02c'

plot_df['color'] = [
    RUBIN_COLOR if "Rubin" in t else CAT_COLORS[c]
    for t, c in zip(plot_df['Telescope'], plot_df['Category'])
]

plot_df['Label'] = plot_df.apply(
    lambda r: f"{r['Year']} · {r['Telescope']}", axis=1
)

# ───────────────────────────────
# Format étendue labels
# ───────────────────────────────

def format_etendue(row):
    value = row['Étendue (m²·deg²)']
    name  = str(row['Telescope']).strip()

    if abs(value) < 1e-9:
        return ""

    if "JWST" in name:
        return f"{value:.2f}"

    formatted = f"{value:.1f}"
    return formatted.rstrip('0').rstrip('.')

plot_df['text_label'] = plot_df.apply(format_etendue, axis=1)

# Data-space label position for log scale
plot_df['label_y'] = plot_df['Étendue (m²·deg²)'] * 1.3

# ───────────────────────────────
# Legend + hover hook
# ───────────────────────────────

Y_MIN, Y_MAX = 0.01, 1000
HIDE_FROM_HOVER = {'color', 'label'}

def add_legend_and_clean_hover(plot, element):
    from bokeh.models import HoverTool, LegendItem, Range1d
    p = plot.state

    # Remove certain fields from hover tooltip
    for tool in p.tools:
        if isinstance(tool, HoverTool) and tool.tooltips:
            tool.tooltips = [(k, v) for k, v in tool.tooltips
                             if k.lower() not in HIDE_FROM_HOVER]

    # Fix y range as Range1d so dummy glyphs below Y_MIN stay clipped
    p.y_range = Range1d(start=Y_MIN, end=Y_MAX)

    # Dummy glyphs positioned below the visible y range — fully colored so
    # legend swatches render correctly, but invisible in the plot itself.
    legend_entries = [
        (SURVEY, CAT_COLORS[SURVEY]),
        (SPACE,  CAT_COLORS[SPACE]),
        (NARROW, CAT_COLORS[NARROW]),
        (FUTURE, CAT_COLORS[FUTURE]),
    ]
    legend_items = []
    for label, color in legend_entries:
        r = p.scatter(x=[0], y=[Y_MIN * 0.01], marker='square', size=12,
                      color=color, line_color='#333333', line_width=0.8)
        legend_items.append(LegendItem(label=label, renderers=[r]))

    # Modify the existing HoloViews legend in place rather than adding a new
    # one — this ensures location is respected by Bokeh.
    if p.legend:
        leg = p.legend[0]
        leg.items = legend_items
        leg.location = 'top_left'
        leg.label_text_font_size = '9pt'
        leg.background_fill_alpha = 0.85
        leg.border_line_color = '#cccccc'

# ───────────────────────────────
# Bars
# ───────────────────────────────

bars = hv.Bars(
    plot_df,
    kdims=['x'],
    vdims=['Étendue (m²·deg²)', 'color']
).opts(
    opts.Bars(
        width=900, height=520,
        color='color',
        line_color='black', line_width=0.5,
        tools=['hover', 'save'],
        toolbar='above',
        xlabel='',
        ylabel='Étendue (m²·deg²) [log scale]',
        title='Survey Telescope Étendue',
        fontsize={'title': 13, 'labels': 11, 'ticks': 9},
        show_grid=True,
        gridstyle={'grid_line_alpha': 0.3},
        xrotation=45,
        logy=True,
        ylim=(Y_MIN, Y_MAX),
        xticks=[(i, label) for i, label in enumerate(plot_df['Label'])],
        hooks=[add_legend_and_clean_hover],
    )
)

# ───────────────────────────────
# Labels
# ───────────────────────────────

labels = hv.Labels(
    plot_df,
    kdims=['x', 'label_y'],
    vdims=['text_label']
).opts(
    opts.Labels(
        text_font_size='9pt',
        text_align='center',
        text_color='black'
    )
)

# ───────────────────────────────
# Overlay
# ───────────────────────────────

bars_with_labels = bars * labels
bars_with_labels

# %% [markdown]
# ## Summary
#
# Using Rubin's M1 annulus geometry ($D_{\mathrm{outer}} = 8.4$ m, $D_{\mathrm{inner}} = 5.012$ m)
# with ~7 % additional obscuration and a 3.5° circular field of view:
#
# $$\boxed{A\Omega \approx 319 \; \mathrm{m^{2}\,deg^{2}}}$$
#
# This is roughly an **order of magnitude** larger than any previous survey telescope.
#
# ---
#
# ## References
#
# **[LOP]** Ivezić, Ž. et al. 2019, *ApJ*, 873, 111
# *"LSST: From Science Drivers to Reference Design and Anticipated Data Products"*
# https://doi.org/10.3847/1538-4357/ab042c · arXiv:0805.2366 · `ls.st/lop`
# *Used for: étendue (319 m²·deg²), effective collecting area (35 m²), FOV diameter (3.5°)*
#
# **[RKN]** Rubin Observatory Key Numbers
# https://rubinobservatory.org/for-scientists/rubin-101/key-numbers
# *Used for: étendue, effective collecting area, FOV*
#
# **[MIR]** Rubin Observatory Mirror page
# https://www.lsst.org/about/tel-site/mirror
# *Used for: M1 outer diameter (8.4 m glass blank), M1 inner diameter, M2 diameter*
#
# **[CLV]** Claver, C. F. et al. — *"An Overview of the LSST Telescope and Site"*
# https://www.lsst.org/sites/default/files/docs/Claver_086.18.pdf
# *Used for: individual mirror dimensions and optical design geometry*
